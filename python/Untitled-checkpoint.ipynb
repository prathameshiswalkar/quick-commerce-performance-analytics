# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %%
# customer = pd.read_csv(r"D:\quick_commerce_capstone\output_data\customers.csv")
# order_status_logs = pd.read_csv(r"D:\quick_commerce_capstone\output_data\order_status_logs.csv")
# products = pd.read_csv(r"D:\quick_commerce_capstone\output_data\products.csv")
# transactions = pd.read_csv(r"D:\quick_commerce_capstone\output_data\transactions.csv")

engine = create_engine(
    "mysql+mysqlconnector://root:mysql999@localhost:3306/capstone"
)

# %%
customers = pd.read_sql('select * from customers', engine)
order_status_logs = pd.read_sql('select * from order_status_logs', engine)
products = pd.read_sql('select * from products', engine)
transactions = pd.read_sql('select * from transactions', engine)
orders = pd.read_sql('select * from orders', engine)

# %%
customers.isnull().sum()[customer.isnull().sum() >0]
# Out:
# email                   0
# address                 0
# last_active_date    15000
# dtype: int64

# %%
customers.columns
# Out:
# Index(['cust_id', 'cust_name', 'email', 'phone', 'gender', 'age', 'city',
#        'address', 'signup_date', 'last_active_date'],
#       dtype='object')

# %%
customers.city = customers.city.str.lower()

# %%
customer.city.value_counts()
# Out:
# city
# delhi        10227
# surat        10148
# indore       10142
# chennai      10054
# jaipur       10039
# pune         10031
# mumbai       10023
# ahmedabad     9993
# bhopal        9988
# kolkata       9938
# bengaluru     9917
# hyderabad     9910
# gurugram      9909
# faridabad     9891
# noida         9790
# Name: count, dtype: int64

# %%
orders.isnull().sum()[orders.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
orders.city.value_counts()
# Out:
# city
# Surat        43513
# Jaipur       43208
# Delhi        42877
# Indore       42795
# Chennai      42579
# Bhopal       42453
# Pune         42214
# Mumbai       42140
# Bengaluru    42095
# Ahmedabad    42019
# Hyderabad    41855
# Gurugram     41837
# Faridabad    41583
# Noida        41560
# Kolkata      41506
# INDORE        9490
# DELHI         9415
# HYDERABAD     9138
# FARIDABAD     9096
# GURUGRAM      9072
# pune          9038
# kolkata       9028
# PUNE          9020
# delhi         9016
# ahmedabad     8953
# bhopal        8944
# MUMBAI        8942
# AHMEDABAD     8922
# JAIPUR        8867
# KOLKATA       8866
# CHENNAI       8862
# noida         8846
# gurugram      8819
# indore        8797
# hyderabad     8764
# mumbai        8733
# SURAT         8719
# bengaluru     8714
# BENGALURU     8711
# surat         8654
# BHOPAL        8591
# jaipur        8555
# faridabad     8547
# chennai       8439
# NOIDA         8208
# Name: count, dtype: int64

# %%
orders.city = orders.city.str.lower()

# %%
orders
# Out:
#         order_id  cust_id  prod_id  quantity  order_date      order_time  \
# 0              1    29185      205         2  2025-02-02 0 days 09:47:06
# 1              2    22791     4838         1  2024-11-18 0 days 10:14:32
# 2              3    52125     4465         1  2025-11-10 0 days 18:51:55
# 3              4   110786     2788         1  2026-01-30 0 days 19:06:05
# 4              5    90166     4946         1  2025-10-23 0 days 21:34:07
# ...          ...      ...      ...       ...         ...             ...
# 899995    899996     8478     3310         5  2025-10-27 0 days 23:41:13
# 899996    899997    17968     2985         1  2024-10-19 0 days 19:32:00
# 899997    899998    78544     2036         3  2024-03-31 0 days 01:02:39
# 899998    899999   146195     4403         2  2024-05-27 0 days 21:43:23
# 899999    900000    26601     3247         5  2025-10-08 0 days 22:28:45
#
#                   order_ts       city  eta_minutes  order_value
# ...

# %%
transactions
# Out:
#         transaction_id  order_id payment_mode payment_status  \
# 0                    1         1          COD        SUCCESS
# 1                    2         2          UPI        SUCCESS
# 2                    3         3  Credit Card        SUCCESS
# 3                    4         4          COD        SUCCESS
# 4                    5         5          UPI        SUCCESS
# ...                ...       ...          ...            ...
# 899995          899996    449996  Net Banking        SUCCESS
# 899996          899997    449997          UPI        SUCCESS
# 899997          899998    449998          UPI        SUCCESS
# 899998          899999    449999          COD        SUCCESS
# 899999          900000    450000       Wallet        PENDING
#
#         transaction_amount          payment_ts
# 0                   240.18 2025-02-02 09:48:08
# 1                   722.73 2024-11-18 10:16:42
# 2                   333.59 2025-11-10 18:52:52
# ...

# %%
transactions.payment_mode.value_counts()
# Out:
# payment_mode
# Net Banking    150386
# Debit Card     150031
# Wallet         149994
# UPI            149964
# Credit Card    149927
# COD            149698
# Name: count, dtype: int64

# %%
products.is_perishable.value_counts()
# Out:
# is_perishable
# 0    3328
# 1    1672
# Name: count, dtype: int64

# %%
products
# Out:
#       prod_id                           prod_name             category  \
# 0           1   Deshpande, Bahri and Mahajan Milk       Dairy & Bakery
# 1           2                   Sood-Tandon Wheat              Staples
# 2           3   Luthra, D’Alia and Ahluwalia Milk       Dairy & Bakery
# 3           4    Nayar, Batra and Srinivas Fruits  Fruits & Vegetables
# 4           5   Mukhopadhyay, Dube and Patla Rice              Staples
# ...       ...                                 ...                  ...
# 4995     4996                    Sheth Inc Cheese       Dairy & Bakery
# 4996     4997  Khanna, Yohannan and Kunda Shampoo        Personal Care
# 4997     4998       Chowdhury-Din Pet Accessories             Pet Care
# 4998     4999                   Samra Ltd Shampoo        Personal Care
# 4999     5000     Kanda, Lalla and Lal Vegetables  Fruits & Vegetables
#
#          sub_category                         brand    price  is_perishable  \
# ...

# %%
order_status_logs.order_status.value_counts()
# Out:
# order_status
# PLACED              900000
# CONFIRMED           900000
# PACKED              900000
# OUT_FOR_DELIVERY    819107
# DELIVERED           819107
# CANCELLED            80893
# Name: count, dtype: int64

# %%
order_status_logs
# Out:
#          status_log_id  order_id      order_status status_date  \
# 0                    1         1            PLACED  2025-02-02
# 1                    2         1         CONFIRMED  2025-02-02
# 2                    3         1            PACKED  2025-02-02
# 3                    4         1  OUT_FOR_DELIVERY  2025-02-02
# 4                    5         1         DELIVERED  2025-02-02
# ...                ...       ...               ...         ...
# 4419102        4419103    450000            PLACED  2024-03-03
# 4419103        4419104    450000         CONFIRMED  2024-03-03
# 4419104        4419105    450000            PACKED  2024-03-03
# 4419105        4419106    450000  OUT_FOR_DELIVERY  2024-03-03
# 4419106        4419107    450000         DELIVERED  2024-03-03
#
#             status_time           status_ts
# 0       0 days 09:53:06 2025-02-02 09:53:06
# 1       0 days 10:15:06 2025-02-02 10:15:06
# 2       0 days 10:35:06 2025-02-02 10:35:06
# ...
